# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # <font style ="color:#ff873d; font-size:36px" ><u>Read the dataset to python environment </u></font>

# %%
#Read the dataset to python environment

df = pd.read_excel("iris.xls")
df
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # <font style ="color:#ff3d74; font-size:36px" ><u>Display the columns in the dataset</u></font>

# %%
#Display the columns in the dataset

df.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# # <font style ="color:#3db857; font-size:36px" ><u>Calculate the mean of each column of the dataset</u></font>

# %%
#Calculate the mean of each column of the dataset

df.mean(axis=0,numeric_only=True)
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# # <font style ="color:#3d9db8; font-size:36px" ><u>Check for the null values present in the dataset</u></font>

# %%
#Check for the null values present in the dataset

df.isna().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# # <font style ="color:#ff8921; font-size:36px" ><u>Visualizations using the dataset</u></font>

# %%
#Visualizations using the dataset

# %% [markdown]
# # <font style ="color:#ff2e54; font-size:24px" >Pie Chart</font>

# %%
plt.figure(figsize=(7,7))
l=df['Classification'].value_counts()
plt.pie(l,labels=l.index,shadow=True, textprops={'fontsize': 14},autopct='%1.2f%%')
plt.legend(fontsize=10,loc="best")
plt.title("Classification - Pie Chart",fontsize=20)
plt.show()

# %% [markdown]
# # <font style ="color:#ff2e54; font-size:24px" >Lineplot - Sepal Width vs Sepal Length</font>

# %%
#Lineplot - Sepal Width vs Sepal Length

plt.figure(figsize=(15,7))
sns.lineplot(x = "SW", y ="SL",hue = "Classification", data = df)

plt.show()

# %% [markdown]
# # <font style ="color:#ff2e54; font-size:24px" >Lineplot - Petal Width vs Petal Length</font>

# %%
#Lineplot - Petal Width vs Petal Length

plt.figure(figsize=(15,7))
sns.lineplot(x = "PW", y ="PL",hue = "Classification", data = df)

plt.show()
